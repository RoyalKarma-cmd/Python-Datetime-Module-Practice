# %%
from datetime import datetime

now = datetime.now()

print(now)
print(now.month)
print(now.year)
print(now.hour)
print(now.minute)
print(now.microsecond)
print(now.day)
print(now.second)
# Out:
# 2026-06-03 02:24:04.175674
# 6
# 2026
# 2
# 24
# 175674
# 3
# 4
